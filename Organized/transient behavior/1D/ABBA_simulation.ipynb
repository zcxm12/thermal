# %%
##########################################################複製區塊
import matplotlib.pyplot as plt
import time
from scipy import signal
from time import sleep
import sys
import meep as mp
import numpy as np
import random
import multiprocessing as multi
#setup some constants and parameters
M=2**16
tsim=7e-12
eps0 = 8.854187e-12
hbar = 1.05457182e-34
c = 2.99792458e8
kb = 1.380649e-23
hdk=7.63823258e-12
deltap = np.sqrt(1/3/eps0/hbar/c)*kb
T=30000
frq_min = 0.5 #150THz
frq_max = 0.8 #240THz
nfreq = 1000
fcen = (frq_min + frq_max)/2
df = frq_max - frq_min
#define square root of Dn function
def Dnsqt(wla,T):
    return np.sqrt(6*hdk**2*wla/(np.exp(hdk*wla/T)-1)/T**2/np.pi)

#generate an array of the square root of Dn function
Dsqt = []
for n in range(1,M):
    Dsqt.append(Dnsqt(2*np.pi*n/tsim,T))

#define how many times to run to average the results
Ncomp= 100
nfreq =  1000
#define the starting sum of the result
epsilonA = 3.7
epsilonB = 12
Efsum = np.zeros(nfreq)
Ens = np.zeros(2*M)
resolution = 60
va = 1
dA = 0.2
dB = 0.8
dpml = 1.0
NAB = 20
sz = 2*dpml+(dA+dB)*NAB+2*va
cell = mp.Vector3(0, 0, sz)
pml_layers = [mp.PML(dpml)]



for i in range(Ncomp):
    
    def random_En(t):
        #generate random numbers
        M0 = np.random.normal(0,1)
        Mlp = np.random.normal(0,1,M-1)
        Nlp = np.random.normal(0,1,M-1)
        MM = np.random.normal(0,1)
    
        #generate the array of the fourier transform of E field, we generate l=0 and l=-M separately. 
        #for l=1 to M-1 and l=-1 to -(M-1) are conjutated to each other. 
        #we contruct the whole array by gluing them together by the order from l=0 -> l=M-1 -> l=-M -> l=-(m-1) -> l=-1
        Ef0 = np.array([M0*np.sqrt(6*hdk/np.pi/T)])
        Eflp = np.multiply((Mlp + 1j*Nlp), Dsqt)
        Eflm = np.flip(np.conjugate(Eflp))
        EfM = np.array([MM*Dnsqt(2*np.pi*M/tsim,T)])
        Ef = np.hstack((Ef0,Eflp,EfM,Eflm))
    
        #we normalize Ef and compute its inverse fast fourier transform
        Efn = deltap*T/np.sqrt(tsim)*Ef
        En = np.fft.ifft(Efn)*M
        return En
    En0 = random_En(1)
    En1 = random_En(1)
    #generate some feedback to check the progress of the loop
    x = i/Ncomp*100
    sys.stdout.write('\r')
    sys.stdout.write("[%-20s] %d%%" % ('a'*int(x), int(x)))
    sys.stdout.flush()
    sleep(0.0001)
    
    
    def source0(t):
        f = int(t*10)
        return En0[f]
    def source1(t):
        f = int(t*10)
        return En1[f]
   


    sources = [mp.Source(mp.CustomSource(src_func=source0),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,random.uniform(-(dA+dB)*NAB/2-va,-(dA+dB)*NAB/2)),
                     ),
              mp.Source(mp.CustomSource(src_func=source1),
                     component=mp.Ex,
                     center=mp.Vector3(0,0,random.uniform((dA+dB)*NAB/2,(dA+dB)*NAB/2+va)),
                     )
              ]
    
    def BlockAB(N, center):
        geometry = []
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,va),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 - va/2 ),
                         material=mp.Medium(epsilon=1)))
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA/2),
                         material=mp.Medium(epsilon=epsilonA)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dA + dB/2),
                         material=mp.Medium(epsilon=epsilonB)))
        geometry = geometry.tolist()
        return geometry
    def BlockBA(N, center):
        geometry = []
        
        for i in range(N):
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dB),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB/2),
                         material=mp.Medium(epsilon=epsilonB)))
            geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,dA),
                         center=mp.Vector3(z=center-(dA+dB)*N/2 + (dA+dB)*i + dB + dA/2),
                         material=mp.Medium(epsilon=epsilonA)))
        geometry = np.append(geometry, mp.Block(mp.Vector3(mp.inf,mp.inf,va),
                         center=mp.Vector3(z=center + (dA+dB)*N/2 + va/2 ),
                         material=mp.Medium(epsilon=1)))
        geometry = geometry.tolist()
        return geometry
    geometry = sum([BlockAB(10,-10*(dA+dB)/2),BlockBA(10,10*(dA+dB)/2)],[])

    
    sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    sources=sources,   
                    dimensions = 1,
                    Courant = 1,
                    resolution=resolution,
                    geometry=geometry)
    
    

    # transmitted flux
    tran_fr = mp.FluxRegion(center=mp.Vector3(0,0,random.uniform(-(dA+dB)*NAB/2,(dA+dB)*NAB/2)))
    tran = sim.add_energy(fcen, df, nfreq, tran_fr)
    
    
    sim.run(until=2090)

    tran_flux = mp.get_magnetic_energy(tran)
    Ts = []
    for i in range(nfreq):
        Ts = np.append(Ts,tran_flux[i])    
    Efsum = Ts
    
    

#average the final result
Efavg = Efsum/Ncomp

#save data to some file or reload file to write more data on it
# Out:
# [                    ] 0%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000155926 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00191402 s
# -----------
# Meep progress: 674.6666666666666/2090.0 = 32.3% done in 4.0s, 8.4s to go
# on time step 40480 (time=674.667), 9.88164e-05 s/step
# Meep progress: 1355.9666666666667/2090.0 = 64.9% done in 8.0s, 4.3s to go
# on time step 81372 (time=1356.2), 9.782e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [a                   ] 1%-----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00198984 s
# -----------
# Meep progress: 1097.1666666666667/2090.0 = 52.5% done in 4.0s, 3.6s to go
# on time step 65830 (time=1097.17), 6.07631e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aa                  ] 2%-----------
# Initializing structure...
# time for choose_chunkdivision = 9.01222e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00142097 s
# -----------
# Meep progress: 1096.5/2090.0 = 52.5% done in 4.0s, 3.6s to go
# on time step 65790 (time=1096.5), 6.0801e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaa                 ] 3%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.70228e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00193501 s
# -----------
# Meep progress: 1095.3166666666666/2090.0 = 52.4% done in 4.0s, 3.6s to go
# on time step 65719 (time=1095.32), 6.0866e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaa                ] 4%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.2016e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00162101 s
# -----------
# Meep progress: 1096.05/2090.0 = 52.4% done in 4.0s, 3.6s to go
# on time step 65763 (time=1096.05), 6.08249e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaa               ] 5%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.70228e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.0016489 s
# -----------
# Meep progress: 1093.6666666666667/2090.0 = 52.3% done in 4.0s, 3.6s to go
# on time step 65620 (time=1093.67), 6.09579e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaa              ] 6%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.2016e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00188804 s
# -----------
# Meep progress: 1099.25/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 65955 (time=1099.25), 6.06479e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaa             ] 7%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.39233e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00161886 s
# -----------
# Meep progress: 1097.4/2090.0 = 52.5% done in 4.0s, 3.6s to go
# on time step 65844 (time=1097.4), 6.07502e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaa            ] 8%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.2016e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00188303 s
# -----------
# Meep progress: 1100.1166666666666/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 66007 (time=1100.12), 6.06007e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaa           ] 9%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.39233e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00225592 s
# -----------
# Meep progress: 1098.7666666666667/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 65926 (time=1098.77), 6.06744e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaa          ] 10%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.10623e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.001899 s
# -----------
# Meep progress: 1100.5166666666667/2090.0 = 52.7% done in 4.0s, 3.6s to go
# on time step 66031 (time=1100.52), 6.058e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaa         ] 11%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.98838e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00174284 s
# -----------
# Meep progress: 1099.4/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 65964 (time=1099.4), 6.06402e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaa        ] 12%-----------
# Initializing structure...
# time for choose_chunkdivision = 7.89165e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00162005 s
# -----------
# Meep progress: 1100.3333333333333/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 66020 (time=1100.33), 6.0588e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaa       ] 13%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.29697e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00188899 s
# -----------
# Meep progress: 1098.4166666666667/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 65905 (time=1098.42), 6.06938e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaa      ] 14%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.17776e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.001899 s
# -----------
# Meep progress: 1097.35/2090.0 = 52.5% done in 4.0s, 3.6s to go
# on time step 65841 (time=1097.35), 6.07533e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaa     ] 15%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.10623e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.001261 s
# -----------
# Meep progress: 1102.9333333333334/2090.0 = 52.8% done in 4.0s, 3.6s to go
# on time step 66176 (time=1102.93), 6.04457e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaa    ] 16%-----------
# Initializing structure...
# time for choose_chunkdivision = 7.98702e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.0018909 s
# -----------
# Meep progress: 1092.7833333333333/2090.0 = 52.3% done in 4.0s, 3.7s to go
# on time step 65567 (time=1092.78), 6.10067e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaa   ] 17%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.29697e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00161886 s
# -----------
# Meep progress: 1096.7833333333333/2090.0 = 52.5% done in 4.0s, 3.6s to go
# on time step 65807 (time=1096.78), 6.07843e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaa  ] 18%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.10623e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.0016129 s
# -----------
# Meep progress: 1098.5833333333333/2090.0 = 52.6% done in 4.0s, 3.6s to go
# on time step 65915 (time=1098.58), 6.06849e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaa ] 19%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.89301e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.000560045 s
# -----------
# Meep progress: 1112.1166666666666/2090.0 = 53.2% done in 4.0s, 3.5s to go
# on time step 66727 (time=1112.12), 5.99463e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaa] 20%-----------
# Initializing structure...
# time for choose_chunkdivision = 7.89165e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.001508 s
# -----------
# Meep progress: 1097.7/2090.0 = 52.5% done in 4.0s, 3.6s to go
# on time step 65862 (time=1097.7), 6.07335e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaa] 21%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.2016e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00190902 s
# -----------
# Meep progress: 1093.5166666666667/2090.0 = 52.3% done in 4.0s, 3.6s to go
# on time step 65611 (time=1093.52), 6.0966e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaa] 22%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.41618e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# ...
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00189686 s
# -----------
# Meep progress: 1092.3/2090.0 = 52.3% done in 4.0s, 3.7s to go
# on time step 65538 (time=1092.3), 6.10342e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 83%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.70228e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00228095 s
# -----------
# Meep progress: 1082.5166666666667/2090.0 = 51.8% done in 4.0s, 3.7s to go
# on time step 64951 (time=1082.52), 6.15863e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 84%-----------
# Initializing structure...
# time for choose_chunkdivision = 9.41753e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00226593 s
# -----------
# Meep progress: 1087.4/2090.0 = 52.0% done in 4.0s, 3.7s to go
# on time step 65244 (time=1087.4), 6.13096e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 85%-----------
# Initializing structure...
# time for choose_chunkdivision = 0.000105858 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00177407 s
# -----------
# Meep progress: 1094.7833333333333/2090.0 = 52.4% done in 4.0s, 3.6s to go
# on time step 65687 (time=1094.78), 6.08955e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 86%-----------
# Initializing structure...
# time for choose_chunkdivision = 9.10759e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00190687 s
# -----------
# Meep progress: 1082.4/2090.0 = 51.8% done in 4.0s, 3.7s to go
# on time step 64944 (time=1082.4), 6.15927e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 87%-----------
# Initializing structure...
# time for choose_chunkdivision = 8.2016e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00175309 s
# -----------
# Meep progress: 1087.65/2090.0 = 52.0% done in 4.0s, 3.7s to go
# on time step 65259 (time=1087.65), 6.12954e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 88%-----------
# Initializing structure...
# time for choose_chunkdivision = 9.29832e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00127006 s
# -----------
# Meep progress: 1093.6333333333332/2090.0 = 52.3% done in 4.0s, 3.6s to go
# on time step 65618 (time=1093.63), 6.09595e-05 s/step
# run 0 finished at t = 2090.0 (125400 timesteps)
# [aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa] 89%-----------
# Initializing structure...
# time for choose_chunkdivision = 9.20296e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 24 with resolution 60
#      block, center = (0,0,-10.5)
#           size (1e+20,1e+20,1)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      block, center = (0,0,-9.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-9.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-8.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-8.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-7.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-7.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-6.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-6.4)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5.9)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      ...(+ 32 objects not shown)...
# time for set_epsilon = 0.00190711 s
# -----------

# %%
freqs = np.linspace(1.5e14,2.4e14,1000)
plt.plot(freqs,Efavg*tsim*eps0*4*np.pi*3/M,'g''-')
plt.xlim(1.5e14,2.4e14)
#plt.yscale("log")
plt.ylim(0,8000e-28)
plt.grid()
plt.savefig('test.png')
plt.show()

np.savez("10ABBA100_2.npz", Efavg_30000 = Efavg)

# %% [markdown]
# ![image.png](attachment:e6a6c867-90c4-4bbe-ab62-ab1abd368dd5.png)
