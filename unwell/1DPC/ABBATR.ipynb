# %%
import numpy as np
Nf = 1000
fmin = 0.5 # 1/micron => 150 THz
fmax = 0.8 # 1/micron => 240 THz
fre = np.linspace(fmin, fmax, Nf)
d1 = 0.2
d2 = 0.8
epsi1 = 3.7
epsi2 = 12
omega = 2 * np.pi * fre

# %%
import meep as mp

resolution = 100                # pixels/um
dpml = 1.0                      # PML thickness
sz = 20 + 2*dpml
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]

fcen = (fmin+fmax)/2          # center frequency
df = (fmax-fmin)                  # frequency width
dimensions = 1

# %%
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df), component=mp.Ex, 
                     center=mp.Vector3(z=-10))]

# %%
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        #Courant = 0.1,
                        resolution=resolution)
sim_vac.reset_meep()

refl_fr = mp.FluxRegion(center=mp.Vector3(z=-10))
refl = sim_vac.add_flux(fcen, df, Nf, refl_fr)
tran_fr = mp.FluxRegion(center=mp.Vector3(z= 10 ))
tran = sim_vac.add_flux(fcen, df, Nf, tran_fr)
   
sim_vac.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex,
                                                        mp.Vector3(z=0), 1e-3))

empty_flux = mp.get_fluxes(tran)
empty_data = sim_vac.get_flux_data(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000380039 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 22 with resolution 100
# time for set_epsilon = 0.001477 s
# -----------
# field decay(t = 50.005): 0.25009677806688885 / 0.25009677806688885 = 1.0
# field decay(t = 100.01): 1.6968103236533206e-12 / 0.25009677806688885 = 6.784614886959901e-12
# run 0 finished at t = 100.01 (20002 timesteps)

# %%
# add a block with n=3.5 for the air-dielectric interface
geometry = []
Np = 6 ## number of repeating

for i in range (Np):
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d1), center=mp.Vector3(z = -6 + d * i),
                     material= mp.Medium(epsilon=epsi1)))
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d2), center=mp.Vector3(z = -6 + d * i + d /2),
                     material= mp.Medium(epsilon=epsi2))) 
for i in range (Np):
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d2), center=mp.Vector3(z = -6 + Np * d  + d * i),
                     material= mp.Medium(epsilon=epsi2)))
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d1), center=mp.Vector3(z = -6 + Np * d + d * i + d /2),
                     material= mp.Medium(epsilon=epsi1)))
    
sim = mp.Simulation(cell_size=cell_size,
                        geometry=geometry,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
tran = sim.add_flux(fcen, df, Nf, tran_fr)
refl = sim.add_flux(fcen, df, Nf, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(z=0), 1e-4))
#sim.run(until=10000)
refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
freqs = mp.get_flux_freqs(refl)

R = np.empty(Nf)
T = np.empty(Nf)
for i in range(Nf):
        R[i] = -refl_flux[i]/empty_flux[i]
        T[i] = tran_flux[i]/empty_flux[i]
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 22 with resolution 100
#      block, center = (0,0,-6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-5.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-4.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-3.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-2.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-1.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 14 objects not shown)...
# time for set_epsilon = 0.003474 s
# -----------
# field decay(t = 50.005): 0.021396691849240503 / 0.021396691849240503 = 1.0
# field decay(t = 100.01): 0.004871561084962479 / 0.021396691849240503 = 0.22767823733159945
# field decay(t = 150.01500000000001): 0.002325585403247887 / 0.021396691849240503 = 0.10868901695803204
# field decay(t = 200.02): 0.001350156227318629 / 0.021396691849240503 = 0.06310116707908536
# field decay(t = 250.025): 0.0010200591845958469 / 0.021396691849240503 = 0.04767368674480653
# field decay(t = 300.03000000000003): 0.0008401587312762889 / 0.021396691849240503 = 0.039265823763597885
# field decay(t = 350.035): 0.0006717903703726394 / 0.021396691849240503 = 0.03139692692244316
# field decay(t = 400.04): 0.0005557011965812731 / 0.021396691849240503 = 0.025971360455938813
# field decay(t = 450.045): 0.0005006927568917682 / 0.021396691849240503 = 0.023400475195867288
# field decay(t = 500.05): 0.00041575966703373877 / 0.021396691849240503 = 0.019431025597935907
# field decay(t = 550.0550000000001): 0.00034997182412304745 / 0.021396691849240503 = 0.01635635202810429
# field decay(t = 600.0600000000001): 0.00030782246214622187 / 0.021396691849240503 = 0.01438645115399689
# field decay(t = 650.065): 0.0002574358235862358 / 0.021396691849240503 = 0.012031571300839842
# field decay(t = 700.07): 0.00021882710139614598 / 0.021396691849240503 = 0.010227146464415407
# field decay(t = 750.075): 0.0001904822927012851 / 0.021396691849240503 = 0.008902417908497684
# field decay(t = 800.08): 0.00016034539613553756 / 0.021396691849240503 = 0.007493933981258378
# field decay(t = 850.085): 0.00013630580904844578 / 0.021396691849240503 = 0.006370415109440579
# on time step 178842 (time=894.21), 2.23662e-05 s/step
# field decay(t = 900.09): 0.00011779264524599766 / 0.021396691849240503 = 0.005505180243560821
# field decay(t = 950.095): 0.00010060502831485825 / 0.021396691849240503 = 0.004701896397055852
# field decay(t = 1000.1): 8.487925473969471e-05 / 0.021396691849240503 = 0.003966933549248997
# field decay(t = 1050.105): 7.322635813731987e-05 / 0.021396691849240503 = 0.0034223214809685223
# field decay(t = 1100.1100000000001): 6.286948072192224e-05 / 0.021396691849240503 = 0.0029382804203984393
# field decay(t = 1150.115): 5.270035546997238e-05 / 0.021396691849240503 = 0.0024630141818789164
# field decay(t = 1200.1200000000001): 4.53939048666862e-05 / 0.021396691849240503 = 0.0021215384689618503
# field decay(t = 1250.125): 3.902225098883708e-05 / 0.021396691849240503 = 0.0018237515997232168
# field decay(t = 1300.13): 3.304977782643962e-05 / 0.021396691849240503 = 0.0015446209189395206
# field decay(t = 1350.135): 2.821153746542608e-05 / 0.021396691849240503 = 0.0013184999655181497
# field decay(t = 1400.14): 2.4256885589319704e-05 / 0.021396691849240503 = 0.001133674577370741
# field decay(t = 1450.145): 2.0755294644472914e-05 / 0.021396691849240503 = 0.0009700235340450371
# field decay(t = 1500.15): 1.7542025065512778e-05 / 0.021396691849240503 = 0.0008198475348017619
# field decay(t = 1550.155): 1.508860470632074e-05 / 0.021396691849240503 = 0.0007051839981915861
# field decay(t = 1600.16): 1.2979511701534935e-05 / 0.021396691849240503 = 0.0006066130125622973
# field decay(t = 1650.165): 1.0883953425477734e-05 / 0.021396691849240503 = 0.0005086745886777853
# field decay(t = 1700.17): 9.36586568518988e-06 / 0.021396691849240503 = 0.00043772494136855696
# field decay(t = 1750.175): 8.062852944065712e-06 / 0.021396691849240503 = 0.0003768270815355931
# field decay(t = 1800.18): 6.7735067931997295e-06 / 0.021396691849240503 = 0.0003165679461537958
# field decay(t = 1850.185): 5.829942945222727e-06 / 0.021396691849240503 = 0.00027246936051143186
# field decay(t = 1900.19): 5.0183479254130285e-06 / 0.021396691849240503 = 0.00023453849598675973
# field decay(t = 1950.195): 4.283043306413759e-06 / 0.021396691849240503 = 0.0002001731546442676
# field decay(t = 2000.2): 3.6269841370888746e-06 / 0.021396691849240503 = 0.00016951144422905814
# field decay(t = 2050.205): 3.1233222156621075e-06 / 0.021396691849240503 = 0.0001459722015753091
# field decay(t = 2100.21): 2.6748840843352564e-06 / 0.021396691849240503 = 0.00012501390884078203
# on time step 428793 (time=2143.97), 1.60032e-05 s/step
# field decay(t = 2150.215): 2.250953059209557e-06 / 0.021396691849240503 = 0.00010520098504337048
# field decay(t = 2200.2200000000003): 1.9370029349122758e-06 / 0.021396691849240503 = 9.052815026548282e-05
# run 0 finished at t = 2200.2200000000003 (440044 timesteps)

# %%
## compare numerical and analytical
from matplotlib import pyplot as plt 
plt.figure(dpi=150)
plt.plot(T,fre*3*10**14,'-',color='g',label='$T_{nur}$')
plt.ylabel("Frequency")
plt.xlabel("Transmission")
#plt.legend(loc="upper right")
plt.ylim(1.5e14,2.4e14)
plt.xlim([0,1])
plt.rcParams.update({'font.size': 20})
plt.grid(True)
plt.savefig('1.5_2.4TR.png')
plt.show()
