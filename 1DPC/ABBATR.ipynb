# %%
import numpy as np
Nf = 1000
fmin = 0.775 # 1/micron => 150 THz
fmax = 0.78 # 1/micron => 240 THz
fre = np.linspace(fmin, fmax, Nf)
d1 = 0.2 # thickness in micron
d2 = 0.8 # thickness in micron
d = d1 + d2
epsi1 = 3.7
epsi2 = 12
omega = 2 * np.pi * fre

# %%
import meep as mp

resolution = 100                # pixels/um
dpml = 1.0                      # PML thickness
sz = 16 + 2*dpml
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]

fcen = (fmin+fmax)/2          # center frequency
df = (fmax-fmin)                  # frequency width
dimensions = 1

# %%
sources = [mp.Source(mp.GaussianSource(fcen,fwidth=df), component=mp.Ex, 
                     center=mp.Vector3(z=-8))]

# %%
sim_vac = mp.Simulation(cell_size=cell_size,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        #Courant = 0.1,
                        resolution=resolution)
sim_vac.reset_meep()

refl_fr = mp.FluxRegion(center=mp.Vector3(z=-8))
refl = sim_vac.add_flux(fcen, df, Nf, refl_fr)
tran_fr = mp.FluxRegion(center=mp.Vector3(z= 8 ))
tran = sim_vac.add_flux(fcen, df, Nf, tran_fr)
   
sim_vac.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex,
                                                        mp.Vector3(z=0), 1e-3))

empty_flux = mp.get_fluxes(tran)
empty_data = sim_vac.get_flux_data(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000319004 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
# time for set_epsilon = 0.00120783 s
# -----------
# field decay(t = 50.005): 2.703266768819953e-11 / 2.703266768819953e-11 = 1.0
# field decay(t = 100.01): 2.795898535115714e-10 / 2.795898535115714e-10 = 1.0
# field decay(t = 150.01500000000001): 2.487470853819097e-09 / 2.487470853819097e-09 = 1.0
# field decay(t = 200.02): 2.011187713905664e-08 / 2.011187713905664e-08 = 1.0
# field decay(t = 250.025): 1.4343373510351376e-07 / 1.4343373510351376e-07 = 1.0
# field decay(t = 300.03000000000003): 9.019413199393115e-07 / 9.019413199393115e-07 = 1.0
# field decay(t = 350.035): 4.896302637670096e-06 / 4.896302637670096e-06 = 1.0
# field decay(t = 400.04): 2.3979488709456216e-05 / 2.3979488709456216e-05 = 1.0
# field decay(t = 450.045): 0.00010355464940015806 / 0.00010355464940015806 = 1.0
# field decay(t = 500.05): 0.0003943237759390417 / 0.0003943237759390417 = 1.0
# field decay(t = 550.0550000000001): 0.001304586927102646 / 0.001304586927102646 = 1.0
# field decay(t = 600.0600000000001): 0.0038690857683702624 / 0.0038690857683702624 = 1.0
# field decay(t = 650.065): 0.010118084380202945 / 0.010118084380202945 = 1.0
# field decay(t = 700.07): 0.023331507328227058 / 0.023331507328227058 = 1.0
# field decay(t = 750.075): 0.0470424839244919 / 0.0470424839244919 = 1.0
# field decay(t = 800.08): 0.08448641748609045 / 0.08448641748609045 = 1.0
# field decay(t = 850.085): 0.13379445016864494 / 0.13379445016864494 = 1.0
# field decay(t = 900.09): 0.18682880620958575 / 0.18682880620958575 = 1.0
# field decay(t = 950.095): 0.22958173146244587 / 0.22958173146244587 = 1.0
# field decay(t = 1000.1): 0.24967581923641108 / 0.24967581923641108 = 1.0
# field decay(t = 1050.105): 0.25013420592011953 / 0.25013420592011953 = 1.0
# field decay(t = 1100.1100000000001): 0.23910478417072525 / 0.25013420592011953 = 0.9559059837145323
# field decay(t = 1150.115): 0.201842277644475 / 0.25013420592011953 = 0.8069359282629798
# field decay(t = 1200.1200000000001): 0.1509653985497748 / 0.25013420592011953 = 0.6035376009228649
# field decay(t = 1250.125): 0.09925524728767467 / 0.25013420592011953 = 0.3968079732340641
# on time step 250298 (time=1251.49), 1.5981e-05 s/step
# field decay(t = 1300.13): 0.057541882211847264 / 0.25013420592011953 = 0.23004403576143956
# field decay(t = 1350.135): 0.029415021167489605 / 0.25013420592011953 = 0.11759695583931173
# field decay(t = 1400.14): 0.013274845363788635 / 0.25013420592011953 = 0.05307089174372242
# field decay(t = 1450.145): 0.005338251682139527 / 0.25013420592011953 = 0.02134155007909754
# field decay(t = 1500.15): 0.0018740919221647706 / 0.25013420592011953 = 0.007492345620107882
# field decay(t = 1550.155): 0.0005801459820155695 / 0.25013420592011953 = 0.0023193388520434477
# field decay(t = 1600.16): 0.0001583572828460664 / 0.25013420592011953 = 0.000633089274070088
# field decay(t = 1650.165): 3.8855767049679666e-05 / 0.25013420592011953 = 0.0001553396781809533
# field decay(t = 1700.17): 8.260542102294036e-06 / 0.25013420592011953 = 3.30244401076918e-05
# field decay(t = 1750.175): 1.5485125700922511e-06 / 0.25013420592011953 = 6.1907269515420425e-06
# field decay(t = 1800.18): 2.5596367774642345e-07 / 0.25013420592011953 = 1.0233053764272672e-06
# field decay(t = 1850.185): 3.8275734297277376e-08 / 0.25013420592011953 = 1.5302079200435604e-07
# field decay(t = 1900.19): 4.9276220595589e-09 / 0.25013420592011953 = 1.9699912858509796e-08
# field decay(t = 1950.195): 5.59410941699547e-10 / 0.25013420592011953 = 2.2364431911331437e-09
# field decay(t = 2000.2): 5.602146436927449e-11 / 0.25013420592011953 = 2.2396562742468323e-10
# run 0 finished at t = 2000.2 (400040 timesteps)

# %%
# add a block with n=3.5 for the air-dielectric interface
geometry = []
Np = 6 ## number of repeating

for i in range (Np):
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d1), center=mp.Vector3(z = -6 + d * i),
                     material= mp.Medium(epsilon=epsi1)))
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d2), center=mp.Vector3(z = -6 + d * i + d /2),
                     material= mp.Medium(epsilon=epsi2))) 
for i in range (Np):
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d2), center=mp.Vector3(z = -6 + Np * d  + d * i),
                     material= mp.Medium(epsilon=epsi2)))
    geometry.append(mp.Block(mp.Vector3(mp.inf,mp.inf,d1), center=mp.Vector3(z = -6 + Np * d + d * i + d /2),
                     material= mp.Medium(epsilon=epsi1)))
    
sim = mp.Simulation(cell_size=cell_size,
                        geometry=geometry,
                        boundary_layers=pml_layers,
                        sources=sources,
                        dimensions=dimensions,
                        resolution=resolution)
tran = sim.add_flux(fcen, df, Nf, tran_fr)
refl = sim.add_flux(fcen, df, Nf, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(z=0), 1e-4))
#sim.run(until=10000)
refl_flux = mp.get_fluxes(refl)
tran_flux = mp.get_fluxes(tran)
freqs = mp.get_flux_freqs(refl)

R = np.empty(Nf)
T = np.empty(Nf)
for i in range(Nf):
        R[i] = -refl_flux[i]/empty_flux[i]
        T[i] = tran_flux[i]/empty_flux[i]
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 8.39233e-05 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 18 with resolution 100
#      block, center = (0,0,-6)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-5.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-5)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-4.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-4)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-3.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-3)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-2.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      block, center = (0,0,-2)
#           size (1e+20,1e+20,0.2)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (3.7,3.7,3.7)
#      block, center = (0,0,-1.5)
#           size (1e+20,1e+20,0.8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
#      ...(+ 14 objects not shown)...
# time for set_epsilon = 0.00198388 s
# -----------
# field decay(t = 50.005): 1.7115006981511059e-12 / 1.7115006981511059e-12 = 1.0
# field decay(t = 100.01): 3.7226479593687843e-11 / 3.7226479593687843e-11 = 1.0
# field decay(t = 150.01500000000001): 4.218679970587038e-10 / 4.218679970587038e-10 = 1.0
# field decay(t = 200.02): 3.859739811472536e-09 / 3.859739811472536e-09 = 1.0
# field decay(t = 250.025): 3.095154154001395e-08 / 3.095154154001395e-08 = 1.0
# field decay(t = 300.03000000000003): 2.184839859076711e-07 / 2.184839859076711e-07 = 1.0
# field decay(t = 350.035): 1.3647567736583668e-06 / 1.3647567736583668e-06 = 1.0
# field decay(t = 400.04): 7.400389791992031e-06 / 7.400389791992031e-06 = 1.0
# field decay(t = 450.045): 3.642182460904244e-05 / 3.642182460904244e-05 = 1.0
# field decay(t = 500.05): 0.0001591766300931332 / 0.0001591766300931332 = 1.0
# field decay(t = 550.0550000000001): 0.0006182341956174005 / 0.0006182341956174005 = 1.0
# field decay(t = 600.0600000000001): 0.002104105248115565 / 0.002104105248115565 = 1.0
# field decay(t = 650.065): 0.00648317041516337 / 0.00648317041516337 = 1.0
# field decay(t = 700.07): 0.017811207978169614 / 0.017811207978169614 = 1.0
# field decay(t = 750.075): 0.04368110116718317 / 0.04368110116718317 = 1.0
# field decay(t = 800.08): 0.09491904978159775 / 0.09491904978159775 = 1.0
# field decay(t = 850.085): 0.18680661932017806 / 0.18680661932017806 = 1.0
# field decay(t = 900.09): 0.3301911216601826 / 0.3301911216601826 = 1.0
# field decay(t = 950.095): 0.5256000560999655 / 0.5256000560999655 = 1.0
# field decay(t = 1000.1): 0.7532241227141239 / 0.7532241227141239 = 1.0
# field decay(t = 1050.105): 0.9846194949836055 / 0.9846194949836055 = 1.0
# field decay(t = 1100.1100000000001): 1.1737917246260934 / 1.1737917246260934 = 1.0
# field decay(t = 1150.115): 1.2844098970214228 / 1.2844098970214228 = 1.0
# field decay(t = 1200.1200000000001): 1.305246906421573 / 1.305246906421573 = 1.0
# field decay(t = 1250.125): 1.29940630066518 / 1.305246906421573 = 0.9955252866506265
# on time step 251551 (time=1257.76), 1.59014e-05 s/step
# field decay(t = 1300.13): 1.2279360622459863 / 1.305246906421573 = 0.9407691803020319
# field decay(t = 1350.135): 1.09502437029022 / 1.305246906421573 = 0.8389404065260779
# field decay(t = 1400.14): 0.9334816837155696 / 1.305246906421573 = 0.7151763234396593
# field decay(t = 1450.145): 0.7709368899986623 / 1.305246906421573 = 0.5906444874190435
# field decay(t = 1500.15): 0.6247228718847501 / 1.305246906421573 = 0.4786242884861318
# field decay(t = 1550.155): 0.5034969712011103 / 1.305246906421573 = 0.38574845013920234
# field decay(t = 1600.16): 0.4041268627266664 / 1.305246906421573 = 0.30961717720872356
# field decay(t = 1650.165): 0.3252237860090257 / 1.305246906421573 = 0.249166486745906
# field decay(t = 1700.17): 0.26261995348536094 / 1.305246906421573 = 0.20120327594213738
# field decay(t = 1750.175): 0.21269313124252337 / 1.305246906421573 = 0.16295241168250432
# field decay(t = 1800.18): 0.1725986209128507 / 1.305246906421573 = 0.132234460824
# field decay(t = 1850.185): 0.14057645895948617 / 1.305246906421573 = 0.10770104741706418
# field decay(t = 1900.19): 0.11426506211868331 / 1.305246906421573 = 0.0875428714341481
# field decay(t = 1950.195): 0.0929001854111116 / 1.305246906421573 = 0.07117441531871088
# field decay(t = 2000.2): 0.07553676174311781 / 1.305246906421573 = 0.057871626717896
# field decay(t = 2050.205): 0.061420437583583024 / 1.305246906421573 = 0.04705656629516289
# field decay(t = 2100.21): 0.04996972344735884 / 1.305246906421573 = 0.03828373252716942
# field decay(t = 2150.215): 0.04072195161827759 / 1.305246906421573 = 0.031198657830892474
# field decay(t = 2200.2200000000003): 0.03311216227555429 / 1.305246906421573 = 0.02536850469642838
# field decay(t = 2250.225): 0.02692441154637432 / 1.305246906421573 = 0.020627830193591115
# field decay(t = 2300.23): 0.021892970846988925 / 1.305246906421573 = 0.016773049404890036
# field decay(t = 2350.235): 0.017801784203951773 / 1.305246906421573 = 0.01363863351552131
# field decay(t = 2400.2400000000002): 0.014512111225981181 / 1.305246906421573 = 0.011118288160335246
# field decay(t = 2450.245): 0.011800207408709051 / 1.305246906421573 = 0.009040594044432679
# field decay(t = 2500.25): 0.009595079496247487 / 1.305246906421573 = 0.007351160496180051
# on time step 507295 (time=2536.47), 1.56407e-05 s/step
# field decay(t = 2550.255): 0.007802034411592683 / 1.305246906421573 = 0.005977439496855437
# field decay(t = 2600.26): 0.006344055028328608 / 1.305246906421573 = 0.004860425255265523
# field decay(t = 2650.265): 0.005158528277800313 / 1.305246906421573 = 0.003952147484450114
# field decay(t = 2700.27): 0.004206084041078967 / 1.305246906421573 = 0.0032224432177435647
# field decay(t = 2750.275): 0.003420083595764032 / 1.305246906421573 = 0.0026202579595767314
# field decay(t = 2800.28): 0.0027809639233554763 / 1.305246906421573 = 0.002130603726906878
# field decay(t = 2850.285): 0.0022612784037740383 / 1.305246906421573 = 0.001732452605441137
# field decay(t = 2900.29): 0.0018387079417439616 / 1.305246906421573 = 0.0014087050754135935
# field decay(t = 2950.295): 0.0014951038337208545 / 1.305246906421573 = 0.0011454567150209058
# field decay(t = 3000.3): 0.0012188301395016645 / 1.305246906421573 = 0.0009337927816608843
# field decay(t = 3050.305): 0.0009910656000064327 / 1.305246906421573 = 0.0007592935827930896
# field decay(t = 3100.31): 0.0008058630983068118 / 1.305246906421573 = 0.0006174028027510463
# field decay(t = 3150.315): 0.0006552700539825119 / 1.305246906421573 = 0.0005020276629338898
# field decay(t = 3200.32): 0.0005328189808135564 / 1.305246906421573 = 0.00040821317268953914
# field decay(t = 3250.3250000000003): 0.00043325005093655824 / 1.305246906421573 = 0.0003319295750137757
# field decay(t = 3300.33): 0.0003532527529435538 / 1.305246906421573 = 0.0002706405594264316
# field decay(t = 3350.335): 0.000287239739826624 / 1.305246906421573 = 0.0002200654438738431
# field decay(t = 3400.34): 0.0002335625898848196 / 1.305246906421573 = 0.00017894130890924539
# field decay(t = 3450.3450000000003): 0.0001899160154496197 / 1.305246906421573 = 0.00014550198473198297
# field decay(t = 3500.35): 0.00015442598045600564 / 1.305246906421573 = 0.00011831170002875197
# field decay(t = 3550.355): 0.00012556808832370206 / 1.305246906421573 = 9.620255578153859e-05
# run 0 finished at t = 3550.355 (710071 timesteps)

# %%
## compare numerical and analytical
from matplotlib import pyplot as plt 
plt.figure(dpi=150)
plt.plot(fre*3.0002e14,T,'-',color='g',label='$T_{nur}$')
plt.xlabel("fre")
plt.ylabel("$T$")
#plt.legend(loc="upper right")
plt.xlim(2.326e14,2.34e14)
plt.ylim([0,1])
plt.grid(True)
#plt.savefig('1.5_2.4.png')
plt.show()
